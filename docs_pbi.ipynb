# %% [markdown]
# # Relatório do PBI no Notebook
#
# Por **Augusto Barros**

# %% [markdown]
# Para incorporar os relatório do PBI no notebook podemos usar a capacidade de renderização de html presente nas células de MarkDown.
#
# Vamos criar um NB vazio:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Convertemos a célula para MD(Atalho: M):
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Vamos localizar o relatório que gostariamos de incorparar, e vamos abri-lo no PBI, no menu de comando clicamos em "Arquivo" e "Inserir relatório" > "Site/Portal":
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Vamos copiar o Iframe e colar no markdown do nosso notebook:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Executamos a célula:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# O Relatório pode não renderizar mesmo, mas exportando o NB para HTML ele é exibido corretamente:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Abrindo o nb convertido:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# É possível fazer ajuste no tamanho da página além de outros controles:
#
# ```html
# <iframe width="1140" height="541.25" src="https://app.powerbi.com/reportEmbed?reportId=f6052cd2-f8d0-4b1a-807c-d1f5b86a7d95&autoAuth=true&ctid=27951710-ebb9-4efb-a4a5-48e460822d4b&config=eyJjbHVzdGVyVXJsIjoiaHR0cHM6Ly93YWJpLWJy123aC1yZWRpcmVjdC5hbmFseXNpcy53aW5kb3dzLm5ldC8ifQ%3D%3D" frameborder="0" allowFullScreen="true"></iframe>
# ```
#
# Nos parâmetros `width`, `height` que controlam largura e altura por exemplo.
#
# ### Exibindo o report com célula de código:
#
# Criamos uma célula com o seguinte código:
#
# ```Python
#
# from IPython.display import HTML
#
# html = 'IFRAME_AQUI'
#
# HTML(html)
# ```
#
#
# ![image.png](attachment:image.png)
#
# > Podemos omitir o código (normalmente espanta usuários convencionais 😂) rodando esse comando de linha no cmd:
#
# `jupyter nbconvert --execute --to html seu_notebook_aqui.ipynb --no-input --no-prompt`
#
# Essa linha executa o NB e converte ele pra HTML, as flags `--no-input --no-prompt` vão omitir o código, exibindo apenas o output das células de código(quando a célula apresentar alguma saída)

# %% [markdown]
# O incorporamento permite a gente fazer o envio do relatório em uma página html isolada do ambiente do PBI, o leitor ainda precisa de acesso ao workspace para ver o relatório.
#
# Espero ter ajudado.
